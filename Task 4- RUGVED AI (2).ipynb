# %% [markdown]
# # Task 4 - codes for the given questions

# %% [markdown]
# ## Basic Code!

# %%
import pandas as pd
import matplotlib as plt

# %%
dataset= pd.read_csv("matches.csv")
dataframe = pd.read_csv("deliveries.csv")

# %%
dataset.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %%
dataset
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# 3                Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Daredevils  Royal Challengers Bangalore           bat
# ..                           ...                          ...           ...
# 751               Mumbai Indians               Mumbai Indians         field
# 752               Mumbai Indians          Chennai Super Kings           bat
# 753               Delhi Capitals               Delhi Capitals         field
# 754          Chennai Super Kings          Chennai Super Kings         field
# 755          Chennai Super Kings               Mumbai Indians           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 0    normal           0          Sunrisers Hyderabad           35
# 1    normal           0       Rising Pune Supergiant            0
# 2    normal           0        Kolkata Knight Riders            0
# 3    normal           0              Kings XI Punjab            0
# 4    normal           0  Royal Challengers Bangalore           15
# ..      ...         ...                          ...          ...
# 751  normal           0               Mumbai Indians            0
# 752  normal           0               Mumbai Indians            0
# 753  normal           0               Delhi Capitals            0
# 754  normal           0          Chennai Super Kings            0
# 755  normal           0               Mumbai Indians            1
#
#      win_by_wickets player_of_match  \
# 0                 0    Yuvraj Singh
# 1                 7       SPD Smith
# 2                10         CA Lynn
# 3                 6      GJ Maxwell
# 4                 0       KM Jadhav
# ..              ...             ...
# 751               9       HH Pandya
# 752               6        AS Yadav
# 753               2         RR Pant
# 754               6    F du Plessis
# 755               0       JJ Bumrah
#
#                                          venue         umpire1  \
# 0    Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1      Maharashtra Cricket Association Stadium  A Nand Kishore
# 2       Saurashtra Cricket Association Stadium     Nitin Menon
# 3                       Holkar Cricket Stadium    AK Chaudhary
# 4                        M Chinnaswamy Stadium             NaN
# ..                                         ...             ...
# 751                           Wankhede Stadium   Nanda Kishore
# 752                  M. A. Chidambaram Stadium     Nigel Llong
# 753                           ACA-VDCA Stadium             NaN
# 754                           ACA-VDCA Stadium   Sundaram Ravi
# 755         Rajiv Gandhi Intl. Cricket Stadium     Nitin Menon
#
#             umpire2                  umpire3
# 0          NJ Llong                      NaN
# 1            S Ravi                      NaN
# 2         CK Nandan                      NaN
# 3     C Shamshuddin                      NaN
# 4               NaN                      NaN
# ..              ...                      ...
# 751        O Nandan                   S Ravi
# 752     Nitin Menon                Ian Gould
# 753             NaN                      NaN
# 754  Bruce Oxenford  Chettithody Shamshuddin
# 755       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %% [markdown]
# ### 1. Count the total number of matches conducted in the year 2008

# %%
len(dataset[dataset['season'] == 2008])
# Out:
# 58

# %% [markdown]
# ### 2. Find the city name where maximum and minimum number of matches were conducted

# %%
dataset['city'].value_counts().idxmax()
# Out:
# 'Mumbai'

# %%
dataset['city'].value_counts().idxmin()
# Out:
# 'Bloemfontein'

# %% [markdown]
# ### 3. Find the total count of matches city wise.

# %%
pd.value_counts(dataset['city'])
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %% [markdown]
# ### 4. Find the team which is maximum and minimum toss winner.

# %%
dataset['toss_winner'].value_counts().idxmax()
# Out:
# 'Mumbai Indians'

# %%
dataset['toss_winner'].value_counts().idxmin()
# Out:
# 'Rising Pune Supergiant'

# %% [markdown]
# ### 6. Count the total number of normal and tie matches

# %%
len(dataset[dataset['result'] == 'normal'])
# Out:
# 743

# %%
len(dataset[dataset['result'] == 'tie'])
# Out:
# 9

# %% [markdown]
# ### 7. Find the team names where the match result is a tie.

# %%
dataset1= dataset[['team1','team2','result']]

# %%
dataset1[dataset1['result']=='tie']
# Out:
#                            team1                        team2 result
# 33                 Gujarat Lions               Mumbai Indians    tie
# 125             Rajasthan Royals        Kolkata Knight Riders    tie
# 189              Kings XI Punjab          Chennai Super Kings    tie
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad    tie
# 400             Delhi Daredevils  Royal Challengers Bangalore    tie
# 475             Rajasthan Royals        Kolkata Knight Riders    tie
# 535             Rajasthan Royals              Kings XI Punjab    tie
# 705        Kolkata Knight Riders               Delhi Capitals    tie
# 746               Mumbai Indians          Sunrisers Hyderabad    tie

# %% [markdown]
# ### 8. Find the team name who won the match by highest runs.

# %%
dataset[['winner']][dataset.win_by_runs == dataset['win_by_runs'].max()]
# Out:
#             winner
# 43  Mumbai Indians

# %% [markdown]
# ### 9. Find the team name who won the match by lowest runs.

# %%
dataset[['winner']][dataset.win_by_runs == dataset['win_by_runs'].min()]
# Out:
#                      winner
# 1    Rising Pune Supergiant
# 2     Kolkata Knight Riders
# 3           Kings XI Punjab
# 5       Sunrisers Hyderabad
# 6            Mumbai Indians
# ..                      ...
# 750         Kings XI Punjab
# 751          Mumbai Indians
# 752          Mumbai Indians
# 753          Delhi Capitals
# 754     Chennai Super Kings
#
# [419 rows x 1 columns]

# %% [markdown]
# ### 10. Find the players who was awarded "Player of the match" more than 3 times.

# %%
motm_awards = pd.value_counts(dataset["player_of_match"])
players_motm_more_than_three = list()
for player, awards_number in motm_awards.items():
    if awards_number > 3:
        players_motm_more_than_three.append(player)
print(players_motm_more_than_three)
# Out:
# ['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner', 'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'MEK Hussey', 'AM Rahane', 'V Kohli', 'V Sehwag', 'DR Smith', 'AD Russell', 'A Mishra', 'JH Kallis', 'KA Pollard', 'SE Marsh', 'AT Rayudu', 'SP Narine', 'Harbhajan Singh', 'SR Tendulkar', 'RA Jadeja', 'UT Yadav', 'Rashid Khan', 'RV Uthappa', 'AC Gilchrist', 'M Vijay', 'RR Pant', 'S Dhawan', 'SL Malinga', 'A Nehra', 'BJ Hodge', 'HH Pandya', 'SC Ganguly', 'SPD Smith', 'PA Patel', 'KC Sangakkara', 'DPMD Jayawardene', 'BB McCullum', 'JP Faulkner', 'AJ Finch', 'DW Steyn', 'Yuvraj Singh', 'SV Samson', 'GJ Maxwell', 'JJ Bumrah', 'Sandeep Sharma', 'JD Unadkat', 'JC Buttler', 'B Kumar', 'KL Rahul', 'KD Karthik', 'JP Duminy', 'MK Pandey', 'NM Coulter-Nile', 'AR Patel', 'N Rana', 'F du Plessis', 'SK Warne', 'CA Lynn', 'SS Iyer', 'ML Hayden', 'KH Pandya']

# %% [markdown]
# ### 11. Find the player who was awarded as player of match maximum times.

# %%
dataset['player_of_match'].value_counts().idxmax()
# Out:
# 'CH Gayle'

# %% [markdown]
# ### 12. Find the venue where the team won the match by highest runs.

# %%
dataset[['venue']][dataset.win_by_runs == dataset['win_by_runs'].max()]
# Out:
#                venue
# 43  Feroz Shah Kotla

# %% [markdown]
# ### 13. Find the venue where the team won the match by lowest runs.

# %%
dataset[['venue']][dataset.win_by_runs == dataset['win_by_runs'].min()]
# Out:
#                                          venue
# 1      Maharashtra Cricket Association Stadium
# 2       Saurashtra Cricket Association Stadium
# 3                       Holkar Cricket Stadium
# 5    Rajiv Gandhi International Stadium, Uppal
# 6                             Wankhede Stadium
# ..                                         ...
# 750                          IS Bindra Stadium
# 751                           Wankhede Stadium
# 752                  M. A. Chidambaram Stadium
# 753                           ACA-VDCA Stadium
# 754                           ACA-VDCA Stadium
#
# [419 rows x 1 columns]

# %% [markdown]
# ### 14. Find the umpires who did umpiring maximum times.

# %%
dataset['umpire1'].value_counts().idxmax()
# Out:
# 'HDPK Dharmasena'

# %% [markdown]
# ### 15. Find the total matches played in each season.

# %%
pd.value_counts(dataset['season'])
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# ### 17. Number of tosses won by each team.

# %%
pd.value_counts(dataset['toss_winner'])
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %% [markdown]
# ### 18. Visualize toss decisions across seasons.

# %%
matches_per_season = dataset.groupby('season').id.count()

toss_decision_percentage = dataset.groupby('season').toss_decision.value_counts().sort_index() / matches_per_season * 100

# %%
toss_decision_percentage.unstack().plot(kind = 'bar', figsize=(12,6), title = 'Toss Decisions', xlabel = 'year', ylabel = 'Percentage');

# %% [markdown]
# ### 19. Find the dismissal kind and visualise using best fit graph

# %%
dismissalkind = dataframe.groupby('dismissal_kind').idxmax()
dismissalkind_percentage = dataframe.groupby('dismissal_kind').dismissal_kind.value_counts().sort_index() / dismissalkind * 100
dismissalkind_percentage.unstack().plot(kind = 'bar', figsize=(12,6), title = 'Dismissal Kind', xlabel = 'year', ylabel = 'Percentage');
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_15936\180410909.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.idxmax is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dismissalkind = dataframe.groupby('dismissal_kind').idxmax()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 dismissalkind = dataframe.groupby('dismissal_kind').idxmax()
# ----> 2 dismissalkind_percentage = dataframe.groupby('dismissal_kind').dismissal_kind.value_counts().sort_index() / dismissalkind * 100
#       3 dismissalkind_percentage.unstack().plot(kind = 'bar', figsize=(12,6), title = 'Dismissal Kind', xlabel = 'year', ylabel = 'Percentage');
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:130, in OpsMixin.__rtruediv__(self, other)
#     128 @unpack_zerodim_and_defer("__rtruediv__")
#     129 def __rtruediv__(self, other):
# --> 130     return self._arith_method(other, roperator.rtruediv)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:7592, in DataFrame._arith_method(self, other, op)
#    7589 axis = 1  # only relevant for Series other case
#    7590 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 7592 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    7594 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7595 return self._construct_result(new_data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\__init__.py:307, in align_method_FRAME(left, right, axis, flex, level)
#     297         if not left.axes[axis].equals(right.index):
#     298             warnings.warn(
#     299                 "Automatic reindexing on DataFrame vs Series comparisons "
#     300                 "is deprecated and will raise ValueError in a future version. "
#    (...)
#     304                 stacklevel=find_stack_level(),
#     305             )
# --> 307     left, right = left.align(
#     308         right, join="outer", axis=axis, level=level, copy=False
#     309     )
#     310     right = _maybe_align_series_as_frame(left, right, axis)
#     312 return left, right
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5090, in DataFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    5076 @doc(NDFrame.align, **_shared_doc_kwargs)
#    5077 def align(
#    5078     self,
#    (...)
#    5088     broadcast_axis: Axis | None = None,
#    5089 ) -> DataFrame:
# -> 5090     return super().align(
#    5091         other,
#    5092         join=join,
#    5093         axis=axis,
#    5094         level=level,
#    5095         copy=copy,
#    5096         fill_value=fill_value,
#    5097         method=method,
#    5098         limit=limit,
#    5099         fill_axis=fill_axis,
#    5100         broadcast_axis=broadcast_axis,
#    5101     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9452, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    9440     return self._align_frame(
#    9441         other,
#    9442         join=join,
#    (...)
#    9449         fill_axis=fill_axis,
#    9450     )
#    9451 elif isinstance(other, ABCSeries):
# -> 9452     return self._align_series(
#    9453         other,
#    9454         join=join,
#    9455         axis=axis,
#    9456         level=level,
#    9457         copy=copy,
#    9458         fill_value=fill_value,
#    9459         method=method,
#    9460         limit=limit,
#    9461         fill_axis=fill_axis,
#    9462     )
#    9463 else:  # pragma: no cover
#    9464     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9581, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    9579 lidx, ridx = None, None
#    9580 if not join_index.equals(other.index):
# -> 9581     join_index, lidx, ridx = join_index.join(
#    9582         other.index, how=join, level=level, return_indexers=True
#    9583     )
#    9585 if lidx is not None:
#    9586     bm_axis = self._get_block_manager_axis(1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:228, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     219 @functools.wraps(meth)
#     220 def join(
#     221     self,
#    (...)
#     226     sort: bool = False,
#     227 ):
# --> 228     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     229     if not return_indexers:
#     230         return join_index
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:4615, in Index.join(self, other, how, level, return_indexers, sort)
#    4613         pass
#    4614     else:
# -> 4615         return self._join_multi(other, how=how)
#    4617 # join on the level
#    4618 if level is not None and (self._is_multi or other._is_multi):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:4739, in Index._join_multi(self, other, how)
#    4737 # need at least 1 in common
#    4738 if not overlap:
# -> 4739     raise ValueError("cannot join with no overlapping index names")
#    4741 if isinstance(self, MultiIndex) and isinstance(other, MultiIndex):
#    4742
#    4743     # Drop the non-matching levels from left and right respectively
#    4744     ldrop_names = sorted(self_names - overlap, key=self_names_order)
#
# ValueError: cannot join with no overlapping index names

# %% [markdown]
# ### 20. Find the top 10 run scorers in IPL and visualise using best fit graph.

# %%
dataframe.head()

# %%
dataframe['batsman'].value_counts().idxmax()

# %% [markdown]
# ### 21. Visualize the Highest MOM award winners

# %%
data1=dataset['player_of_match'].value_counts()
data1.plot(kind = 'bar', figsize=(100,100), title = 'Player of Match', xlabel = 'Player name', ylabel = 'number of times');

# %% [markdown]
# ### 22. Find the total number of played matches by each team.

# %%
a=dataset.groupby('team1')['team1'].count()

# %%
b=dataset.groupby('team2')['team2'].count()

# %%
d=a+b
display(d)

# %% [markdown]
# ### 23. Compare total played matches vs winning matches vs win rate.
